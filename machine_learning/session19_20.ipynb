# %% [markdown]
# <a href="https://colab.research.google.com/github/hoseinm444/googleColab_works/blob/machine_learning_exersise/machine_learning/session19_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Session 19 :correlation

# %% [markdown]
# ##چک کردن ارتباط بین پارامتر ها , نحوه ارتباط ۲ متغیر

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

df = pd.read_csv("housing.csv")

# %% [markdown]
# ##ایجاد داده ترین و طبقه بندی مقادیر  به نسبت درست

# %%
df["median_income_categories"] =pd.cut(df["median_income"], bins=[0.0,1.5,3.0,4.5,6,np.inf],labels=[1,2,3,4,5])

# %%
from sklearn.model_selection import train_test_split


str_train_set, str_test_set= train_test_split(df,
                                              test_size = 0.2,
                                              stratify=  df["median_income_categories"],
                                              random_state= 40)

# %%
str_train_set =str_train_set.drop("median_income_categories",axis=1)
str_test_set =str_test_set.drop("median_income_categories",axis=1)

# %%
train=str_train_set

# %% [markdown]
# ##correlation

# %%
train.corr()

# %%
train.corr()["median_house_value"]

# %% [markdown]
# ## رسمcorrelation

# %%
sns.scatterplot(data=train,
                x="median_income",
                y="median_house_value",
                alpha=0.2)
# Out:
# <Axes: xlabel='median_income', ylabel='median_house_value'>

# %% [markdown]
# #Session 20 :Attribute Combiniation

# %% [markdown]
# ##ترکیب کردن ستون هایی که اطلاعات بیشتری در اختیار ما قرار می دهند

# %%
train["rooms_per_house"]=train["total_rooms"]/train["households"]
train["bedrooms_ratio"]=train["total_bedrooms"]/train["total_rooms"]
train

# %%
train.corr()["median_house_value"]
# Out:
# <ipython-input-21-58701e32a644>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train.corr()["median_house_value"]
# longitude            -0.051167
# latitude             -0.137691
# housing_median_age    0.105329
# total_rooms           0.138007
# total_bedrooms        0.052814
# population           -0.021544
# households            0.070014
# median_income         0.686865
# median_house_value    1.000000
# rooms_per_house       0.159500
# bedrooms_ratio       -0.255178
# Name: median_house_value, dtype: float64
